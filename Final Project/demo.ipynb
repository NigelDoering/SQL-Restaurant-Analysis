# %%
import os
import pandas as pd

# %%
t1 = pd.read_csv('data/chefmozcuisine.csv')
t2 = pd.read_csv('data/chefmozparking.csv')
t3 = pd.read_csv('data/chefmozhours4.csv')
t4 = pd.read_csv('data/chefmozaccepts.csv')
t5 = pd.read_csv('data/geoplaces2.csv')

# %%
combined = pd.merge(t1, t2, on='placeID')
combined = pd.merge(combined, t3, on='placeID')
combined = pd.merge(combined, t4, on='placeID')
combined
# Out:
#       placeID        Rcuisine parking_lot         hours                  days  \
# 0      135110         Spanish        none  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 1      135110         Spanish        none  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 2      135110         Spanish        none  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 3      135110         Spanish        none  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 4      135110         Spanish        none  08:00-19:00;  Mon;Tue;Wed;Thu;Fri;
# 5      135110         Spanish        none  00:00-00:00;                  Sat;
# 6      135110         Spanish        none  00:00-00:00;                  Sat;
# 7      135110         Spanish        none  00:00-00:00;                  Sat;
# 8      135110         Spanish        none  00:00-00:00;                  Sat;
# 9      135110         Spanish        none  00:00-00:00;                  Sat;
# 10     135110         Spanish        none  00:00-00:00;                  Sun;
# ...
